# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("titanic.csv")

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375    B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500   C22        S   11    NaN
# 2   2.0000      1      2  113781  151.5500   C22        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500   C22        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500   C22        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# missing
data.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
missing=[c for c in data.columns if data[c].isnull().any()]

# %%
missing
# Out:
# ['age', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest']

# %%
data["age"].mean()
# Out:
# 29.8811345124283

# %%
data["age"].isnull().groupby(data["survived"]).mean()
# Out:
# survived
# 0    0.234858
# 1    0.146000
# Name: age, dtype: float64

# %%
data["age"]=data["age"].fillna(data["age"].mean())

# %%
data["age"].isnull().sum()
# Out:
# 0

# %%
cat=[i for i in data.columns if data[i].dtypes=="O"]

# %%
cat
# Out:
# ['name', 'sex', 'ticket', 'cabin', 'embarked', 'boat', 'home.dest']

# %%
data["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data["embarked"].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
pd.get_dummies(data,columns=["sex"],drop_first=True)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#             age  sibsp  parch  ticket      fare cabin embarked boat   body  \
# ...

# %%
len(data["cabin"].value_counts().sort_values(ascending=False))
# Out:
# 181

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
data["embarked"]=ohe.fit_transform(data["embarked"].values.reshape(-1,1)).toarray()

# %%
import scipy.stats as stats
def plotting(data,var):
    plt.subplot(1,3,1)
    plt.hist(data[var])
    plt.subplot(1,3,2)
    stats.probplot(data[var],dist="norm",plot=plt)
    plt.subplot(1,3,3)
    sns.boxplot(data[var])
plotting(data,"age")

# %%
data["age"].shape
# Out:
# (1309,)

# %%
lower=data["age"].mean()-3*data["age"].std()
upper=data["age"].mean()+3*data["age"].std()
outlier=data[(data["age"]>upper) |( data["age"]<lower)]
outlier
# Out:
#       pclass  survived                                               name  \
# 9          1         0                            Artagaveytia, Mr. Ramon
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81         1         0                       Crosby, Capt. Edward Gifford
# 135        1         0                          Goldschmidt, Mr. George B
# 506        2         0                        Mitchell, Mr. Henry Michael
# 727        3         0                               Connors, Mr. Patrick
# 1235       3         0                                Svensson, Mr. Johan
#
#          sex   age  sibsp  parch      ticket     fare cabin  embarked boat  \
# 9       male  71.0      0      0    PC 17609  49.5042   NaN       1.0  NaN
# 14      male  80.0      0      0       27042  30.0000   A23       0.0    B
# 61    female  76.0      1      0       19877  78.8500   C46       0.0    6
# ...

# %%
numer=[c for c in data.columns if data[c].dtypes in ["int64","float64"]]

# %%
data[numer]
# Out:
#       pclass  survived        age  sibsp  parch      fare  embarked   body
# 0          1         1  29.000000      0      0  211.3375       0.0    NaN
# 1          1         1   0.916700      1      2  151.5500       0.0    NaN
# 2          1         0   2.000000      1      2  151.5500       0.0    NaN
# 3          1         0  30.000000      1      2  151.5500       0.0  135.0
# 4          1         0  25.000000      1      2  151.5500       0.0    NaN
# ...      ...       ...        ...    ...    ...       ...       ...    ...
# 1304       3         0  14.500000      1      0   14.4542       1.0  328.0
# 1305       3         0  29.881135      1      0   14.4542       1.0    NaN
# 1306       3         0  26.500000      0      0    7.2250       1.0  304.0
# 1307       3         0  27.000000      0      0    7.2250       1.0    NaN
# 1308       3         0  29.000000      0      0    7.8750       0.0    NaN
#
# [1309 rows x 8 columns]

# %%
sns.heatmap(data[numer].corr(),annot=True)
# Out:
# <Axes: >

# %%
x=pd.DataFrame(data[numer])

# %%
x
# Out:
#       pclass  survived        age  sibsp  parch      fare  embarked   body
# 0          1         1  29.000000      0      0  211.3375       0.0    NaN
# 1          1         1   0.916700      1      2  151.5500       0.0    NaN
# 2          1         0   2.000000      1      2  151.5500       0.0    NaN
# 3          1         0  30.000000      1      2  151.5500       0.0  135.0
# 4          1         0  25.000000      1      2  151.5500       0.0    NaN
# ...      ...       ...        ...    ...    ...       ...       ...    ...
# 1304       3         0  14.500000      1      0   14.4542       1.0  328.0
# 1305       3         0  29.881135      1      0   14.4542       1.0    NaN
# 1306       3         0  26.500000      0      0    7.2250       1.0  304.0
# 1307       3         0  27.000000      0      0    7.2250       1.0    NaN
# 1308       3         0  29.000000      0      0    7.8750       0.0    NaN
#
# [1309 rows x 8 columns]

# %%
x.corr()
# Out:
#             pclass  survived       age     sibsp     parch      fare  \
# pclass    1.000000 -0.312469 -0.366370  0.060832  0.018322 -0.558629
# survived -0.312469  1.000000 -0.050199 -0.027825  0.082660  0.244265
# age      -0.366370 -0.050199  1.000000 -0.190747 -0.130872  0.171892
# sibsp     0.060832 -0.027825 -0.190747  1.000000  0.373587  0.160238
# parch     0.018322  0.082660 -0.130872  0.373587  1.000000  0.221539
# fare     -0.558629  0.244265  0.171892  0.160238  0.221539  1.000000
# embarked -0.269658  0.182123  0.076179 -0.048396 -0.008635  0.286269
# body     -0.034642       NaN  0.059059 -0.099961  0.051099 -0.043110
#
#           embarked      body
# pclass   -0.269658 -0.034642
# survived  0.182123       NaN
# age       0.076179  0.059059
# sibsp    -0.048396 -0.099961
# parch    -0.008635  0.051099
# fare      0.286269 -0.043110
# embarked  1.000000  0.006242
# body      0.006242  1.000000

# %%
sns.heatmap(x.corr(),annot=True)
# Out:
# <Axes: >

# %%
def correlations(dataset,threshold):
    col=set()
    matrix=dataset.corr()
    for i in range(len(matrix.columns)):
        for j in range(i):
            if(matrix.iloc[i,j]>threshold):
                col_na=matrix.columns[i]
                col.add(col_na)
    return col
feat=correlations(x,0.4)  
feat
# Out:
# set()

# %%
bins=[2,12,18,30,50]
labels=["child","teen","adult","elderly"]
data["Age_groups"]=pd.cut(data["age"],bins,labels=labels)
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare cabin  embarked boat  \
# ...

# %%
data["ticket"].str.split().str[1]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1304    NaN
# 1305    NaN
# 1306    NaN
# 1307    NaN
# 1308    NaN
# Name: ticket, Length: 1309, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 sns.countplot(data["survived"],hue="survived")
#       2 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
data["survived"].value_counts()
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64
